# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Seu código aqui
df_percentuais = pd.DataFrame({
    'Matemática': (df_mat['Qt_acertos'] / 24),
    'Português':  (df_por['Qt_acertos'] / 18),
    'Geografia':  (df_geo['Qt_acertos'] / 8),
    'Inglês':     (df_ing['Qt_acertos'] / 8),
    'História':   (df_his['Qt_acertos'] / 8),
    'Física':     (df_fis['Qt_acertos'] / 12),
    'Química':    (df_qui['Qt_acertos'] / 12)
})
df_percentuais
# Out:
#     Matemática  Português  Geografia  Inglês  História    Física   Química
# 0     0.250000   0.388889      0.875   0.375     0.125  0.666667  0.250000
# 1     0.791667   0.555556      0.000   0.000     0.000  0.916667  0.666667
# 2     0.583333   0.888889      0.000   0.625     0.875  0.333333  0.333333
# 3     0.416667   0.388889      0.375   0.500     0.000  0.000000  0.666667
# 4     0.291667   0.111111      0.250   0.875     0.000  0.750000  0.250000
# ..         ...        ...        ...     ...       ...       ...       ...
# 95    0.250000   0.222222      0.875   0.125     0.500  0.750000  0.250000
# 96    0.333333   0.055556      0.500   0.750     0.125  0.333333  0.250000
# 97    0.958333   0.277778      0.000   0.250     0.500  0.083333  0.416667
# 98    0.000000   0.555556      0.375   0.125     0.625  0.833333  0.916667
# 99    0.458333   0.833333      0.000   0.125     0.750  0.583333  0.166667
#
# [100 rows x 7 columns]

# %%
# 2) Seu código aqui
df_total_acertos = pd.DataFrame({
    'Matemática': df_mat['Qt_acertos'],
    'Português':  df_por['Qt_acertos'],
    'Geografia':  df_geo['Qt_acertos'],
    'Inglês':     df_ing['Qt_acertos'],
    'História':   df_his['Qt_acertos'],
    'Física':     df_fis['Qt_acertos'],
    'Química':    df_qui['Qt_acertos']
})
df_total_acertos['Total_Acertos'] = df_total_acertos.sum(axis=1)
df_total_acertos['Total_Acertos']
# Out:
# 0     35
# 1     48
# 2     50
# 3     32
# 4     30
#       ..
# 95    34
# 96    27
# 97    40
# 98    40
# 99    42
# Name: Total_Acertos, Length: 100, dtype: int64

# %%
# 3) Seu código aqui
total_questoes = 24 + 18 + 8 + 8 + 8 + 12 + 12
df_total_acertos['Percentual_Geral'] = (df_total_acertos['Total_Acertos'] / total_questoes) * 100
df_total_acertos['Percentual_Geral'] = df_total_acertos['Percentual_Geral'].round(2)
df_total_acertos['Percentual_Geral']
# Out:
# 0     38.89
# 1     53.33
# 2     55.56
# 3     35.56
# 4     33.33
#       ...
# 95    37.78
# 96    30.00
# 97    44.44
# 98    44.44
# 99    46.67
# Name: Percentual_Geral, Length: 100, dtype: float64

# %%
# 4) Seu código aqui
aprovados = df_total_acertos[df_total_acertos['Percentual_Geral'] > 45.0]
num_aprovados = (df_total_acertos['Percentual_Geral'] > 45.0).sum()
print('\n')
print(f'O numero de alunos aprovado é {num_aprovados}')
aprovados
# Out:
# O numero de alunos aprovado é 47
#     Matemática  Português  Geografia  Inglês  História  Física  Química  \
# 1           19         10          0       0         0      11        8
# 2           14         16          0       5         7       4        4
# 5           20          2          5       3         2       9        9
# 7           18          4          4       7         7       1        8
# 8           22          9          2       7         6       5        7
# 11          23          6          2       0         6       4        2
# 12          20          8          3       7         1       0        3
# 17          21         15          2       2         4       2        6
# 18          20          4          3       5         3      11        4
# 20          23         11          6       5         6       2        0
# 24          20          2          7       5         3      11        2
# 27          21         13          1       5         7       3        0
# ...

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
desqualificados = df_total_acertos[
    (df_total_acertos['Matemática'] == 0) |
    (df_total_acertos['Física'] == 0) |
    (df_total_acertos['Química'] == 0)
]
desqualificados
# Out:
#     Matemática  Português  Geografia  Inglês  História  Física  Química  \
# 3           10          7          3       4         0       0        8
# 6            6          0          7       7         5       0        4
# 10          10          8          3       2         1       7        0
# 12          20          8          3       7         1       0        3
# 14           7         11          1       7         1       4        0
# 20          23         11          6       5         6       2        0
# 25           0          4          7       4         0       4        8
# 26          11         14          6       2         7       0        0
# 27          21         13          1       5         7       3        0
# 33          14          8          0       5         6       6        0
# 35          11         14          6       3         3       0       11
# 49           8          1          1       0         1       0        8
# ...

# %%
num_desqualificados = desqualificados.shape[0]
print(f'O número de alunos desqualificados é {num_desqualificados}')
# Out:
# O número de alunos desqualificados é 23

# %%
media_hist_geo_desqualificados = desqualificados[['História', 'Geografia']].mean()
print("Média dos desqualificados, em História e Geografia:")
print(media_hist_geo_desqualificados)
# Out:
# Média dos desqualificados, em História e Geografia:
# História     3.434783
# Geografia    3.217391
# dtype: float64

# %%
aprovados_segunda_fase = aprovados.drop(index=desqualificados.index, errors='ignore')

print(f"Total de aprovados para a segunda fase: {aprovados_segunda_fase.shape[0]}")
aprovados_segunda_fase
# Out:
# Total de aprovados para a segunda fase: 41
#     Matemática  Português  Geografia  Inglês  História  Física  Química  \
# 1           19         10          0       0         0      11        8
# 2           14         16          0       5         7       4        4
# 5           20          2          5       3         2       9        9
# 7           18          4          4       7         7       1        8
# 8           22          9          2       7         6       5        7
# 11          23          6          2       0         6       4        2
# 17          21         15          2       2         4       2        6
# 18          20          4          3       5         3      11        4
# 24          20          2          7       5         3      11        2
# 29          16          0          0       2         7      11        8
# 31          15         13          3       1         3       9       10
# ...

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
df = pd.read_csv('registros de vacinacao covid ACRE.csv',sep=';')
df.head()
# Out:
#                                  document_id  \
# 0  78b9fe2d-5ce6-44fb-b722-9e1fe91d1050-i0b0
# 1  fad14228-9e6e-4895-8dd5-d590bceaa136-i0b0
# 2  78c958a5-9b46-4549-9ddd-515b960dad9c-i0b0
# 3  fadbea84-381c-4e84-920c-fdd146d96744-i0b0
# 4  6fa4658b-b9ea-485c-a056-9e0ab9635e32-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  22c01b1c23c1a5eddfeb1223c7376c1194b99054c1ae2a...              14
# 1  9f7c6a218929e7cd3763aaf6174b3bd104a79d5f9fb796...              16
# 2  33615ee202e9bbd0857368de2db23fdbae35a990024cd9...              31
# 3  59ea685f572ee8be8c48fef8962167a2b96ab5627613a2...              30
# 4  2b4d02be47f1fd9b31e7c09b8f1cf2772b8059a53f6786...              52
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              2008-04-16                          M                        3
# 1              2005-06-27                          M                       99
# ...

# %%
# 1) Sua solução aqui
numero_de_registros = df.shape[0]
print(f'Número de vacinas registradas: {numero_de_registros}')
# Out:
# Número de vacinas registradas: 390911

# %%
# 2)
n_pacientes_vacinados= df['paciente_id'].nunique()
print(f'O número de pacientes vacinados foi de: {n_pacientes_vacinados}')
# Out:
# O número de pacientes vacinados foi de: 318850

# %%
# 3)
print(df['vacina_descricao_dose'].unique())
print(df['vacina_descricao_dose'] == '1ª Dose')
primeira_dose = df[df['vacina_descricao_dose'] == '1ª Dose']
n_pacientes_primeira_dose = primeira_dose['paciente_id'].nunique()
print('\n')
print(f'O numero de pacientes unicos a receber a primeria dose foi de: {n_pacientes_primeira_dose}')
# Out:
# ['Reforço' '1ª Dose' '2ª Dose' 'Única' '2º Reforço' 'Dose'
#  'Dose Adicional' '1ª Dose Revacinação' '3ª Dose' 'Revacinação'
#  '1º Reforço' '3ª Dose Revacinação' '2ª Dose Revacinação' '3º Reforço'
#  '4ª Dose Revacinação' '5ª Dose Revacinação']
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 390906    False
# 390907     True
# 390908    False
# 390909    False
# 390910    False
# Name: vacina_descricao_dose, Length: 390911, dtype: bool
#
#
# O numero de pacientes unicos a receber a primeria dose foi de: 143753

# %%
# 4)
paciente_menos_18 = df[df['paciente_idade'] < 18]
pacientes_unic_menos_18 = paciente_menos_18['paciente_id'].nunique()
print(f'O número de pacientes vacinados com menos de 18 anos foi de: {pacientes_unic_menos_18}')
# Out:
# O número de pacientes vacinados com menos de 18 anos foi de: 69726

# %%
# 5)
print(df.columns)
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem'],
# ...

# %%
estabelecimentos_unicos = df['estabelecimento_valor'].nunique()
print(f"Número de estabelecimentos que aplicaram vacina no Acre foram: {estabelecimentos_unicos}")
# Out:
# Número de estabelecimentos que aplicaram vacina no Acre foram: 229

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1)
df_menores18 = df[df['paciente_idade']<18].copy()
df_menores18
# Out:
#                                       document_id  \
# 0       78b9fe2d-5ce6-44fb-b722-9e1fe91d1050-i0b0
# 1       fad14228-9e6e-4895-8dd5-d590bceaa136-i0b0
# 11      fbc8c10d-e07f-45a8-bcc1-e35283e01f2b-i0b0
# 12      fbe28799-25d1-4201-ba7b-535d6364923d-i0b0
# 14      d704d5e0-db08-4864-93ff-1c49ba1c4e44-i0b0
# ...                                           ...
# 390886  9fe4881a-7e8c-4ba9-a25f-871d5e70fa04-i0b0
# 390887  a01f03f2-644f-445b-91bc-cfe4ff76123e-i0b0
# 390890  a088a98d-510a-4cde-91cc-03cef6a8701a-i0b0
# 390900  a1437081-b1c3-4b56-bf06-f14e19a1e007-i0b0
# 390909  a21f33ee-cdca-455c-9ade-55a6d387c9e8-i0b0
#
#                                               paciente_id  paciente_idade  \
# 0       22c01b1c23c1a5eddfeb1223c7376c1194b99054c1ae2a...              14
# 1       9f7c6a218929e7cd3763aaf6174b3bd104a79d5f9fb796...              16
# 11      641d0e0d0185cef7922557a8db22d22c4032fe003a199e...               7
# ...

# %%
# 2)
colunas = df_menores18.columns.tolist()
colunas
# Out:
# ['document_id',
#  'paciente_id',
#  'paciente_idade',
#  'paciente_dataNascimento',
#  'paciente_enumSexoBiologico',
#  'paciente_racaCor_codigo',
#  'paciente_racaCor_valor',
#  'paciente_endereco_coIbgeMunicipio',
#  'paciente_endereco_coPais',
#  'paciente_endereco_nmMunicipio',
#  'paciente_endereco_nmPais',
#  'paciente_endereco_uf',
#  'paciente_endereco_cep',
#  'paciente_nacionalidade_enumNacionalidade',
#  'estabelecimento_valor',
#  'estabelecimento_razaoSocial',
#  'estalecimento_noFantasia',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf',
#  'vacina_grupoAtendimento_codigo',
#  'vacina_grupoAtendimento_nome',
#  'vacina_categoria_codigo',
#  'vacina_categoria_nome',
#  'vacina_lote',
#  'vacina_fabricante_nome',
#  'vacina_fabricante_referencia',
#  'vacina_dataAplicacao',
#  'vacina_descricao_dose',
#  'vacina_codigo',
#  'vacina_nome',
#  'sistema_origem']

# %%
# 3)
contagem_categorias = df_menores18['vacina_categoria_nome'].value_counts()
contagem_categorias
# Out:
# 0            Faixa Etária
# 1            Faixa Etária
# 11                    NaN
# 12                    NaN
# 14           Faixa Etária
#                ...
# 390886                NaN
# 390887       Faixa Etária
# 390890       Faixa Etária
# 390900    Povos Indígenas
# 390909    Povos Indígenas
# Name: vacina_categoria_nome, Length: 79220, dtype: object

# %%
# 4)
colunas_estabelecimento = [col for col in df.columns if col.startswith('estabelecimento')]
colunas_estabelecimento.append('estalecimento_noFantasia')  # Uma das colunas está com erro de digitação então adicionamos ela a parte 

df_estabelecimentos = df_menores18.loc[:, colunas_estabelecimento]
df_estabelecimentos_unicos = df_estabelecimentos.drop_duplicates()

# %%
# 5)
df_estabelecimentos = df_menores18.loc[:, colunas_estabelecimento]

# %%
df_estabelecimentos_unicos = df_estabelecimentos.drop_duplicates()

# %%
contagem_vacinas = df_menores18.groupby('estabelecimento_valor').size().reset_index(name='qtd_vacinas_menores_18')
df_final = pd.merge(df_estabelecimentos_unicos, contagem_vacinas, on='estabelecimento_valor', how='inner')
df_final
# Out:
#      estabelecimento_valor                       estabelecimento_razaoSocial  \
# 0                  2001039                  PREFEITURA MUNICIPAL DE CAPIXABA
# 1                  6917291                PREFEITURA MUNICIPAL DE RIO BRANCO
# 2                  2002922                     SECRETARIA MUNICIPAL DE SAUDE
# 3                  2000482                PREFEITURA MUNICIPAL DE RIO BRANCO
# 4                  3810771                  PREFEITURA MUNICIPAL DE TARAUACA
# ..                     ...                                               ...
# 208                9846433             PREFEITURA MUNICIPAL DE MANOEL URBANO
# 209                2001357        SECRETARIA MUNICIPAL DE SAUDE DE BRASILEIA
# 210                 197599                CENTRAL MUNICIPAL DE REDE DE FRIOS
# 211                6076017  ALERGOYMUNE CLINICA DE ALERGIA E IMUNIZACAO LTDA
# 212                6411312         PREFEITURA MUNICIPAL DE PLACIDO DE CASTRO
#
# ...
